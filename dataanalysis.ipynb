# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv("Survey_Responses(2).csv")
# Out:
#      <input type="file" id="files-ca5066e0-4eb5-4dff-b8a3-c79b227e6d64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca5066e0-4eb5-4dff-b8a3-c79b227e6d64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Survey_Responses(2).csv')
df
# Out:
#                      Timestamp What is your current academic level?  \
# 0    2025/03/15 4:29:44 pm EET                              level 2
# 1    2025/03/15 4:44:12 pm EET                              level 2
# 2    2025/03/15 4:49:22 pm EET                              level 2
# 3    2025/03/15 6:10:58 pm EET                              level 2
# 4    2025/03/15 7:30:04 pm EET                              level 2
# 5   2025/03/16 12:11:50 am EET                              level 2
# 6    2025/03/17 9:50:43 pm EET                              level 2
# 7   2025/03/17 10:15:56 pm EET                              level 2
# 8    2025/03/18 4:31:41 am EET                              level 2
# 9    2025/03/18 8:57:00 pm EET                              level 2
# 10   2025/03/18 9:05:22 pm EET                              level 1
# 11   2025/03/18 9:58:26 pm EET                              level 4
# 12  2025/03/11 09:58:43 PM EET                              level 3
# ...

# %%
df.drop(columns=['Timestamp'], errors='ignore', inplace=True)
df.drop(columns=['What is your current GPA or grade point average?'], errors='ignore', inplace=True)
df
# Out:
#    What is your current academic level?  \
# 0                               level 2
# 1                               level 2
# 2                               level 2
# 3                               level 2
# 4                               level 2
# 5                               level 2
# 6                               level 2
# 7                               level 2
# 8                               level 2
# 9                               level 2
# 10                              level 1
# 11                              level 4
# 12                              level 3
# 13                              level 4
# 14                              level 4
# 15                              level 4
# 16                              level 1
# 17                              level 4
# 18                              level 1
# 19                              level 3
# 20                              level 3
# 21                              level 1
# ...

# %%
df=df.rename(columns={'What is your current academic level?': 'level',
                        'On average, how often do you miss classes?': 'classes','How you catch up if you missed a classes?':'catching up','Do you feel that regular attendance helps you stay more engaged with the course material?':'feel for attendance'})
df
# Out:
#       level classes How you catch up if you missed a class?  \
# 0   level 2   never          Lecture notes from a classmate
# 1   level 2   never                              self study
# 2   level 2   Often          Lecture notes from a classmate
# 3   level 2   never                              self study
# 4   level 2  rarely                              self study
# 5   level 2   Often                              self study
# 6   level 2  rarely          Lecture notes from a classmate
# 7   level 2   never                              self study
# 8   level 2  rarely                              self study
# 9   level 2  rarely          Lecture notes from a classmate
# 10  level 1  rarely          Lecture notes from a classmate
# 11  level 4   Often                              self study
# 12  level 3   never          Lecture notes from a classmate
# 13  level 4   never                              self study
# 14  level 4  Always          Lecture notes from a classmate
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(data= df,  x ='Attendance', y='GPA')

# %%
sns.boxplot(data= df, x= 'Attendance', y='GPA');

# %%
df.describe()
# Out:
#             GPA  Attendance
# count  32.00000   32.000000
# mean    2.65875    1.218750
# std     0.77091    1.099395
# min     1.56000    0.000000
# 25%     1.97000    0.000000
# 50%     2.53000    1.000000
# 75%     3.42000    2.000000
# max     3.80000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   level                                    32 non-null     object
#  1   classes                                  32 non-null     object
#  2   How you catch up if you missed a class?  32 non-null     object
#  3   feel for attendance                      32 non-null     object
#  4   GPA                                      32 non-null     float64
#  5   Attendance                               32 non-null     int64
#  6   Academic Level                           32 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.9+ KB

# %%
plt.hist(data = df, x='GPA', bins=20);

# %%
plt.hist(data = df, x='Attendance', bins=20);

# %%
mean_gpa = df["GPA"].mean()
mode_gpa = df["GPA"].mode()[0]

# %%
mean_attendance = df["Attendance"].mean()
mode_attendance = df["Attendance"].mode()[0]
